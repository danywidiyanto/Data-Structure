# %%
l=[]
panjang=int(input("Masukkan panjang list"))
print("Masukkan angka")
for i in range (panjang):
    data=int(input())
    l.append(data)
search=int(input("Masukkan angka:"))
iterasi=0
l.sort()
position=0
last=len(l)-1
found = False
while position <= last and not found:
    mid = (position + last)//2
    if l[mid]==search:
        found=True
    else:
        if search<l[mid]:
            last=mid-1
        else:
            position=mid+1
    if found:
        print("Angka yang dicari ketemu:")
        print("terdapat pada list index ke:",posisi)
        print("iterasi ke:",iterasi+1)
    else:
        iterasi+=1
        print ("iterasi ke:",iterasi)
# Out:
# Masukkan panjang list20
# Masukkan angka
# 88
# 95
# 43
# 65
# 12
# 34
# 56
# 78
# 90
# 55
# 11
# 2
# 4
# 7
# 45
# 78
# 52
# 66
# 134
# 60
# Masukkan angka:45
# iterasi ke: 1
# iterasi ke: 2
# iterasi ke: 3
# Angka yang dicari ketemu:
# terdapat pada list index ke: 7
# iterasi ke: 4

# %%
l=[]
panjang=int(input("Masukkan panjang list"))
print("Masukkan angka")
for i in range (panjang):
    data=int(input())
    l.append(data)
iterasi=0
cari=int(input("Masukkan angka yang dicari"))
l.sort()
posisi=0
akhir=len(l)-1
found = False
while posisi <= akhir and not found:
    if l[posisi]==cari:
        found=True
    else:
        posisi= posisi+1
    if found:
        print("Angka yang dicari ketemu:")
        print("terdapat pada list index ke:",posisi)
        print("iterasi ke:",iterasi+1)
    else:
        iterasi+=1
        print ("iterasi ke:",iterasi)
# Out:
# Masukkan panjang list20
# Masukkan angka
# 88
# 95
# 43
# 65
# 12
# 34
# 56
# 78
# 90
# 55
# 11
# 2
# 4
# 7
# 45
# 78
# 52
# 66
# 134
# 60
# Masukkan angka yang dicari45
# iterasi ke: 1
# iterasi ke: 2
# iterasi ke: 3
# iterasi ke: 4
# iterasi ke: 5
# iterasi ke: 6
# iterasi ke: 7
# Angka yang dicari ketemu:
# terdapat pada list index ke: 7
# iterasi ke: 8

# %%
l=[]
panjang=int(input("Masukkan panjang list"))
print("Masukkan angka")
for i in range (panjang):
    data=int(input())
    l.append(data)
search=int(input("Masukkan angka:"))
iterasi=0
l.sort()
position=0
last=len(l)-1
found = False
while position <= last and not found:
    mid = (position + last)//2
    if l[mid]==search:
        found=True
    else:
        if search<l[mid]:
            last=mid
        else:
            position=mid
    if found:
        print("Angka yang dicari ketemu:")
        print("terdapat pada list index ke:",posisi)
        print("iterasi ke:",iterasi+1)
    else:
        iterasi+=1
        print ("iterasi ke:",iterasi)
# Out:
# Masukkan panjang list20
# Masukkan angka
# 88
# 95
# 43
# 65
# 12
# 34
# 56
# 78
# 90
# 55
# 11
# 2
# 4
# 7
# 45
# 78
# 52
# 66
# 134
# 60
# Masukkan angka:45
# iterasi ke: 1
# iterasi ke: 2
# iterasi ke: 3
# Angka yang dicari ketemu:
# terdapat pada list index ke: 7
# iterasi ke: 4
